# %%
import numpy as np
import matplotlib.pyplot as plt

def norm(v):
    return np.vdot(v,v)

def dist(x,y):
    return norm(y - x)

R = 0.03

m1 = np.array([0.17, [0, 0.5], [0,-1]])
m2 = np.array([0.17, [0, 0], [0,0]])

E_tot = 0.5*m1*norm(m1[2])**2 + 0.5*m2*norm(m1[2])**2

t_f = 20
t = 0
dt = 0.01

def collision(m1, m2):
    return abs(dist(m1[1], m2[1])) < R

while t < t_f:
    if collision(m1, m2):
        m1[2][0] = 
    t += dt
