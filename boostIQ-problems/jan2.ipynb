# %%
import numpy as np

grid = np.array([[1, 1, 2, 2, 2, 2, 2, 2, 2, 2], 
                 [2, 0, 2, 2, 2, 2, 2, 2, 2, 2], 
                 [2, 2, 2, 1, 2, 2, 0, 2, 2, 1], 
                 [2, 2, 2, 2, 2, 2, 2, 2, 2, 2], 
                 [1, 2, 2, 1, 2, 2, 2, 1, 2, 1], 
                 [2, 2, 0, 2, 2, 0, 0, 2, 2, 2], 
                 [2, 1, 2, 2, 2, 2, 2, 2, 2, 2], 
                 [0, 2, 2, 1, 1, 2, 1, 2, 2, 1], 
                 [2, 2, 2, 1, 2, 2, 1, 2, 2, 2], 
                 [2, 2, 2, 2, 2, 2, 2, 2, 2, 1]])

# %% [markdown]
# $$ \psi_-(x_1, x_2, x_3) = \frac{1}{\sqrt{6}} \begin{vmatrix}
# \psi_a(x_1) & \psi_b(x_1) & \psi_c(x_1) \\
# \psi_a(x_2) & \psi_b(x_2) & \psi_c(x_2) \\
# \psi_a(x_3) & \psi_b(x_3) & \psi_c(x_3)
# \end{vmatrix} $$
