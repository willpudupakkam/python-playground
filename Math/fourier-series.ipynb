# %%
from typing import *
from sympy import *
import scipy as sp

def f(x):
    return x

def fourier(func: Callable, a: int, b: int):
    L = b - a

    a_n = []
    b_n = []
# Out:
# (0.5, 5.551115123125783e-15)
